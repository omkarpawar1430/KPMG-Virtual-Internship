# %%
# Import Libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
old_data_path = "/home/omkar/Omkar Pawar/Data Science/KPMG Virtual Internship/Data/cleaned_old_customer_data.xlsx"

# old customers data: odf: 
odf = pd.read_excel(old_data_path)

# %%
odf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19408 entries, 0 to 19407
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           19408 non-null  int64
#  1   customer_id                          19408 non-null  int64
#  2   gender                               19408 non-null  object
#  3   past_3_years_bike_related_purchases  19408 non-null  int64
#  4   DOB                                  19408 non-null  datetime64[ns]
#  5   job_title                            19408 non-null  object
#  6   job_industry_category                19408 non-null  object
#  7   wealth_segment                       19408 non-null  object
#  8   deceased_indicator                   19408 non-null  object
#  9   owns_car                             19408 non-null  object
#  10  tenure                               19408 non-null  float64
#  11  full_name                            19408 non-null  object
#  12  address                              19408 non-null  object
#  13  postcode                             19408 non-null  int64
#  14  state                                19408 non-null  object
#  15  country                              19408 non-null  object
#  16  property_valuation                   19408 non-null  int64
#  17  transaction_id                       19408 non-null  int64
#  18  product_id                           19408 non-null  int64
#  19  transaction_date                     19408 non-null  datetime64[ns]
#  20  online_order                         19408 non-null  bool
#  21  order_status                         19408 non-null  object
#  22  brand                                19408 non-null  object
#  23  product_line                         19408 non-null  object
#  24  product_class                        19408 non-null  object
#  25  product_size                         19408 non-null  object
#  26  list_price                           19408 non-null  float64
#  27  standard_cost                        19408 non-null  float64
#  28  product_first_sold_date              19408 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(8), object(15)
# memory usage: 4.2+ MB

# %%
odf.head()
# Out:
#    Unnamed: 0  customer_id  gender  past_3_years_bike_related_purchases
# 0           0            1  Female                                   93  \
# 1           1            1  Female                                   93
# 2           2            1  Female                                   93
# 3           3            1  Female                                   93
# 4           4            1  Female                                   93
#
#          DOB            job_title job_industry_category wealth_segment
# 0 1953-10-12  Executive Secretary                Health  Mass Customer  \
# 1 1953-10-12  Executive Secretary                Health  Mass Customer
# 2 1953-10-12  Executive Secretary                Health  Mass Customer
# 3 1953-10-12  Executive Secretary                Health  Mass Customer
# 4 1953-10-12  Executive Secretary                Health  Mass Customer
#
#   deceased_indicator owns_car  ...  transaction_date online_order
# 0                  N        Y  ...        2017-12-23        False  \
# 1                  N        Y  ...        2017-04-06         True
# 2                  N        Y  ...        2017-05-11         True
# 3                  N        Y  ...        2017-01-05        False
# 4                  N        Y  ...        2017-02-21        False
#
#   order_status           brand product_line product_class  product_size
# 0     Approved      OHM Cycles     Standard        medium        medium  \
# 1     Approved           Solex     Standard        medium        medium
# 2     Approved   Trek Bicycles         Road           low         small
# 3     Approved  Norco Bicycles     Standard        medium        medium
# 4     Approved           Solex     Standard        medium        medium
#
#    list_price  standard_cost product_first_sold_date
# 0      235.63         125.07                   38482
# 1     1577.53         826.51                   39526
# 2     1720.70        1531.42                   37823
# 3      360.40         270.30                   37873
# 4       71.49          53.62                   38573
#
# [5 rows x 29 columns]

# %%
import datetime as dt

odf['DOB'] = pd.to_datetime(odf['DOB'])
current_year = dt.datetime.now().year

odf['age'] = current_year - odf['DOB'].dt.year

print(odf[['DOB', 'age']])
# Out:
#              DOB  age
# 0     1953-10-12   70
# 1     1953-10-12   70
# 2     1953-10-12   70
# 3     1953-10-12   70
# 4     1953-10-12   70
# ...          ...  ...
# 19403 1967-07-21   56
# 19404 1967-07-21   56
# 19405 1967-07-21   56
# 19406 1967-07-21   56
# 19407 1967-07-21   56
#
# [19408 rows x 2 columns]

# %%
odf['age'].min()
# Out:
# 21

# %%
odf['age'].max()
# Out:
# 92

# %%
# which gender purchased more bicycle ?
temp_view = odf.drop_duplicates(subset=['customer_id'])
temp_view[['gender', 'past_3_years_bike_related_purchases', 'age']]
# Out:
#        gender  past_3_years_bike_related_purchases  age
# 0      Female                                   93   70
# 11       Male                                   81   43
# 14       Male                                   33   62
# 16     Female                                   56   46
# 22       Male                                   35   57
# ...       ...                                  ...  ...
# 19382    Male                                   99   37
# 19386  Female                                   73   37
# 19389  Female                                   28   28
# 19395    Male                                   29   44
# 19402  Female                                   71   56
#
# [3486 rows x 3 columns]

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the plot
plt.figure(figsize=(8, 6))

# Customize Seaborn settings
sns.set_palette("pastel")  # Change the color palette
sns.set(style="whitegrid")  # Add grid lines

# Create a countplot using Seaborn
ax = sns.countplot(x='gender', data=temp_view)

# Add count numbers on top of each bar
for p in ax.patches: # to iterate over each bar in the count plot
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', 
                fontsize=10, color='red', weight='bold',
                bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Remove the spines (borders) for a cleaner look
sns.despine()

# Add title to the plot
plt.title('Gender Distribution')

# Display the plot
plt.show()

# %% [markdown]
# - slightly more females are buying bicycles than male customers.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the plot
plt.figure(figsize=(8, 6))

# Customize Seaborn settings
sns.set_palette("pastel")  # Change the color palette
sns.set(style="whitegrid")  # Add grid lines

# Create a countplot using Seaborn
ax = sns.countplot(x='wealth_segment', data=temp_view)

# Add count numbers on top of each bar
for p in ax.patches: # to iterate over each bar in the count plot
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', 
                fontsize=10, color='red', weight='bold',
                bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Remove the spines (borders) for a cleaner look
sns.despine()

# Add title to the plot
plt.title('Wealth Segment')

# Display the plot
plt.show()

# %% [markdown]
# Mass customers are significantly more that affluent customers and hight net worth customers.

# %% [markdown]
# --------

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='past_3_years_bike_related_purchases', data=temp_view, hue='gender', palette='Set1')
plt.title('Scatter Plot - Age vs Bike Purchases with Gender Differentiation')
plt.xlabel('Age')
plt.ylabel('Past 3 Years Bike Related Purchases')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# We can clearly say that our customers are from range of 20 to 70 with very few exceptions.

# %% [markdown]
# ------

# %%
# owns a car?
temp_view['owns_car'].value_counts()
# Out:
# owns_car
# Y    1766
# N    1720
# Name: count, dtype: int64

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the plot
plt.figure(figsize=(8, 6))

# Customize Seaborn settings
sns.set_palette("pastel")  # Change the color palette
sns.set(style="whitegrid")  # Add grid lines

# Create a countplot using Seaborn
ax = sns.countplot(x='owns_car', data=temp_view)

# Add count numbers on top of each bar
for p in ax.patches: # to iterate over each bar in the count plot
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', 
                fontsize=10, color='red', weight='bold',
                bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Remove the spines (borders) for a cleaner look
sns.despine()

# Add title to the plot
plt.title('Owns Car Distribution')

# Display the plot
plt.show()

# %% [markdown]
# the difference between people with car or without car is negligible.

# %% [markdown]
# ---------
